# %% [markdown]
# # lab6_rnns_text_classification
# - Task 0: Data loading & label encoding
# - Task 1: Pipeline TF-IDF + Logistic Regression
# - Task 2: Pipeline Word2Vec (Trung bình) + Dense Layer
# - Task 3: Mô hình Nâng cao (Embedding Pre-trained + LSTM)
# - Task 4: Mô hình Nâng cao (Embedding học từ đầu + LSTM)
# - Task 5: Đánh giá, So sánh và Phân tích

# %%
# Imports and utilities
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report, f1_score, log_loss
from gensim.models import Word2Vec
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
import pandas as pd
# Dữ liệu có thể được phân tách bằng tab và không có header
df_train = pd.read_csv('C:\\Users\\ADMIN\\.vscode\\NLP_APP\\hwu\\train.csv', sep=',')
df_val = pd.read_csv('C:\\Users\\ADMIN\\.vscode\\NLP_APP\\hwu\\val.csv', sep=',')
df_test = pd.read_csv('C:\\Users\\ADMIN\\.vscode\\NLP_APP\\hwu\\test.csv', sep=',')
print("Train shape:", df_train.shape)
print("Validation shape:", df_val.shape)
print("Test shape:", df_test.shape)
df_train.head()
# Out:
# Train shape: (8954, 2)
# Validation shape: (1076, 2)
# Test shape: (1076, 2)
#                                                 text     category
# 0                what alarms do i have set right now  alarm_query
# 1                    checkout today alarm of meeting  alarm_query
# 2                              report alarm settings  alarm_query
# 3  see see for me the alarms that you have set to...  alarm_query
# 4                       is there an alarm for ten am  alarm_query

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()

all_intents = pd.concat(
    [df_train['category'], 
     df_val['category'], 
     df_test['category']]).dropna()

labelEncoder.fit(all_intents)
y_train = labelEncoder.transform(df_train['category'])
y_val = labelEncoder.transform(df_val['category'])
y_test = labelEncoder.transform(df_test['category'])

print("Number of classes:", len(labelEncoder.classes_))
# Out:
# Number of classes: 64

# %% [markdown]
# **Task 1: Pipeline TF-IDF + Logistic Regression**

# %%
tfidf_lr_pipeline = make_pipeline(
    TfidfVectorizer(max_features=5000),
    LogisticRegression(max_iter=1000, random_state=RANDOM_SEED)
)

tfidf_lr_pipeline.fit(df_train['text'], y_train)
y_pred = tfidf_lr_pipeline.predict(df_test['text'])

print(classification_report(y_test, y_pred, target_names=labelEncoder.classes_))
# Out:
#                           precision    recall  f1-score   support
#
#              alarm_query       0.90      0.95      0.92        19
#             alarm_remove       1.00      0.73      0.84        11
#                alarm_set       0.77      0.89      0.83        19
#        audio_volume_down       1.00      0.75      0.86         8
#        audio_volume_mute       0.92      0.80      0.86        15
#          audio_volume_up       0.93      1.00      0.96        13
#           calendar_query       0.45      0.53      0.49        19
#          calendar_remove       0.89      0.89      0.89        19
#             calendar_set       0.87      0.68      0.76        19
#           cooking_recipe       0.59      0.68      0.63        19
#         datetime_convert       0.67      0.75      0.71         8
#           datetime_query       0.74      0.89      0.81        19
#         email_addcontact       0.78      0.88      0.82         8
#              email_query       0.83      0.79      0.81        19
#       email_querycontact       0.92      0.63      0.75        19
#          email_sendemail       0.81      0.89      0.85        19
#           general_affirm       1.00      1.00      1.00        19
#      general_commandstop       1.00      1.00      1.00        19
#          general_confirm       1.00      1.00      1.00        19
#         general_dontcare       0.90      1.00      0.95        19
#          general_explain       1.00      0.95      0.97        19
#             general_joke       1.00      1.00      1.00        12
#           general_negate       0.95      1.00      0.97        19
#           general_praise       0.95      1.00      0.97        19
#           general_quirky       0.36      0.26      0.30        19
#           general_repeat       0.90      1.00      0.95        19
#             iot_cleaning       1.00      1.00      1.00        16
#               iot_coffee       1.00      0.95      0.97        19
#      iot_hue_lightchange       0.75      0.79      0.77        19
#         iot_hue_lightdim       0.91      0.83      0.87        12
#         iot_hue_lightoff       0.89      0.89      0.89        19
#          iot_hue_lighton       0.67      0.67      0.67         3
#          iot_hue_lightup       1.00      0.86      0.92        14
#             iot_wemo_off       0.80      0.89      0.84         9
#              iot_wemo_on       0.78      1.00      0.88         7
#        lists_createoradd       0.68      0.79      0.73        19
#              lists_query       0.75      0.79      0.77        19
#             lists_remove       0.85      0.89      0.87        19
#           music_likeness       0.65      0.61      0.63        18
#              music_query       0.71      0.53      0.61        19
#           music_settings       1.00      0.57      0.73         7
#               news_query       0.75      0.63      0.69        19
#           play_audiobook       0.95      0.95      0.95        19
#                play_game       0.81      0.68      0.74        19
#               play_music       0.58      0.74      0.65        19
#            play_podcasts       1.00      0.84      0.91        19
#               play_radio       0.89      0.84      0.86        19
#              qa_currency       0.94      0.89      0.92        19
#            qa_definition       0.82      0.95      0.88        19
#               qa_factoid       0.48      0.58      0.52        19
#                 qa_maths       0.92      0.86      0.89        14
#                 qa_stock       1.00      0.95      0.97        19
#    recommendation_events       0.83      0.79      0.81        19
# recommendation_locations       0.81      0.89      0.85        19
#    recommendation_movies       1.00      1.00      1.00        10
#              social_post       0.95      1.00      0.97        19
#             social_query       0.80      0.89      0.84        18
#           takeaway_order       0.83      0.79      0.81        19
#           takeaway_query       0.89      0.89      0.89        19
#          transport_query       0.68      0.79      0.73        19
#           transport_taxi       1.00      1.00      1.00        18
#         transport_ticket       0.94      0.79      0.86        19
#        transport_traffic       1.00      0.95      0.97        19
#            weather_query       0.62      0.68      0.65        19
#
#                 accuracy                           0.84      1076
#                macro avg       0.85      0.83      0.84      1076
#             weighted avg       0.84      0.84      0.84      1076

# %% [markdown]
# **Task 2: Pipeline Word2Vec (Trung bình) + Dense Layer**

# %%
# 1. Huấn luyện mô hình Word2Vec trên dữ liệu text của bạn
sentences = [text.split() for text in df_train['text']]
w2v_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

# 2. Viết hàm để chuyển mỗi câu thành vector trung bình
def sentence_to_avg_vector(text, model):
    word = text.split()
    word_vector = []
    for w in word:
        if w in model.wv:
            word_vector.append(model.wv[w])
    if len(word_vector) == 0:
        return np.zeros(model.vector_size)
    return np.mean(word_vector, axis=0)

# 3. Tạo dữ liệu train/val/test X_train_avg, X_val_avg, X_test_avg
X_train_avg = np.array([sentence_to_avg_vector(t, w2v_model) for t in df_train['text']])
X_val_avg = np.array([sentence_to_avg_vector(t, w2v_model) for t in df_val['text']])
X_test_avg = np.array([sentence_to_avg_vector(t, w2v_model) for t in df_test['text']])

# 4. Xây dựng mô hình Sequential của Keras
model = Sequential([
    Dense(128, activation='relu', input_shape=(w2v_model.vector_size,)),
    Dropout(0.5),
    Dense(len(labelEncoder.classes_), activation='softmax')])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

# 5. Compile, huấn luyện và đánh giá mô hình
history = model.fit(X_train_avg, y_train,
                    validation_data=(X_val_avg, y_val),
                    epochs=150,
                    batch_size=64)

print(classification_report(y_test, model.predict(X_test_avg).argmax(axis=1), target_names=labelEncoder.classes_))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        12,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,184 (82.75 KB)
#  Trainable params: 21,184 (82.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0141 - loss: 4.1649 - val_accuracy: 0.0362 - val_loss: 4.1124
# Epoch 2/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0296 - loss: 4.1139 - val_accuracy: 0.0762 - val_loss: 4.0727
# Epoch 3/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0454 - loss: 4.0722 - val_accuracy: 0.0688 - val_loss: 4.0089
# Epoch 4/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0555 - loss: 4.0122 - val_accuracy: 0.0688 - val_loss: 3.9294
# Epoch 5/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0634 - loss: 3.9346 - val_accuracy: 0.0753 - val_loss: 3.8418
# Epoch 6/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0660 - loss: 3.8543 - val_accuracy: 0.0818 - val_loss: 3.7624
# Epoch 7/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0768 - loss: 3.7843 - val_accuracy: 0.0874 - val_loss: 3.6916
# Epoch 8/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0871 - loss: 3.7300 - val_accuracy: 0.1022 - val_loss: 3.6325
# Epoch 9/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0943 - loss: 3.6625 - val_accuracy: 0.1115 - val_loss: 3.5803
# Epoch 10/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1007 - loss: 3.6169 - val_accuracy: 0.1180 - val_loss: 3.5406
# Epoch 11/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1045 - loss: 3.5756 - val_accuracy: 0.1320 - val_loss: 3.4912
# Epoch 12/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1175 - loss: 3.5313 - val_accuracy: 0.1385 - val_loss: 3.4511
# Epoch 13/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1141 - loss: 3.5069 - val_accuracy: 0.1468 - val_loss: 3.4215
# Epoch 14/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1274 - loss: 3.4655 - val_accuracy: 0.1608 - val_loss: 3.3815
# Epoch 15/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1243 - loss: 3.4461 - val_accuracy: 0.1626 - val_loss: 3.3597
# Epoch 16/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1316 - loss: 3.4099 - val_accuracy: 0.1589 - val_loss: 3.3352
# Epoch 17/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1351 - loss: 3.3883 - val_accuracy: 0.1599 - val_loss: 3.3132
# Epoch 18/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1401 - loss: 3.3481 - val_accuracy: 0.1757 - val_loss: 3.2757
# Epoch 19/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1474 - loss: 3.3287 - val_accuracy: 0.1691 - val_loss: 3.2682
# Epoch 20/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1551 - loss: 3.3115 - val_accuracy: 0.1775 - val_loss: 3.2321
# Epoch 21/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1487 - loss: 3.2923 - val_accuracy: 0.1794 - val_loss: 3.2078
# Epoch 22/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1559 - loss: 3.2656 - val_accuracy: 0.1775 - val_loss: 3.1980
# Epoch 23/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1554 - loss: 3.2478 - val_accuracy: 0.1840 - val_loss: 3.1902
# Epoch 24/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1604 - loss: 3.2402 - val_accuracy: 0.1887 - val_loss: 3.1602
# Epoch 25/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1634 - loss: 3.2191 - val_accuracy: 0.1868 - val_loss: 3.1462
# Epoch 26/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1676 - loss: 3.1965 - val_accuracy: 0.1998 - val_loss: 3.1278
# Epoch 27/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1823 - loss: 3.1896 - val_accuracy: 0.2100 - val_loss: 3.1083
# Epoch 28/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1745 - loss: 3.1758 - val_accuracy: 0.2100 - val_loss: 3.0942
# Epoch 29/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2985 - loss: 2.6125 - val_accuracy: 0.3188 - val_loss: 2.4970
# Epoch 127/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3059 - loss: 2.6006 - val_accuracy: 0.3234 - val_loss: 2.4929
# Epoch 128/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2932 - loss: 2.6238 - val_accuracy: 0.3299 - val_loss: 2.4958
# Epoch 129/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2964 - loss: 2.6117 - val_accuracy: 0.3364 - val_loss: 2.4963
# Epoch 130/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2980 - loss: 2.5783 - val_accuracy: 0.3299 - val_loss: 2.4869
# Epoch 131/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3013 - loss: 2.6056 - val_accuracy: 0.3160 - val_loss: 2.4967
# Epoch 132/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2997 - loss: 2.6035 - val_accuracy: 0.3327 - val_loss: 2.4712
# Epoch 133/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2899 - loss: 2.6033 - val_accuracy: 0.3290 - val_loss: 2.4859
# Epoch 134/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3027 - loss: 2.5962 - val_accuracy: 0.3374 - val_loss: 2.4826
# Epoch 135/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3017 - loss: 2.5879 - val_accuracy: 0.3336 - val_loss: 2.4613
# Epoch 136/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3077 - loss: 2.5825 - val_accuracy: 0.3188 - val_loss: 2.4814
# Epoch 137/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3104 - loss: 2.5837 - val_accuracy: 0.3271 - val_loss: 2.4732
# Epoch 138/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3077 - loss: 2.5862 - val_accuracy: 0.3374 - val_loss: 2.4642
# Epoch 139/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3098 - loss: 2.5725 - val_accuracy: 0.3290 - val_loss: 2.4622
# Epoch 140/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3121 - loss: 2.5599 - val_accuracy: 0.3439 - val_loss: 2.4567
# Epoch 141/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3145 - loss: 2.5776 - val_accuracy: 0.3411 - val_loss: 2.4516
# Epoch 142/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3013 - loss: 2.5693 - val_accuracy: 0.3336 - val_loss: 2.4564
# Epoch 143/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3088 - loss: 2.5680 - val_accuracy: 0.3383 - val_loss: 2.4621
# Epoch 144/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3071 - loss: 2.5734 - val_accuracy: 0.3327 - val_loss: 2.4359
# Epoch 145/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3143 - loss: 2.5612 - val_accuracy: 0.3271 - val_loss: 2.4494
# Epoch 146/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3107 - loss: 2.5629 - val_accuracy: 0.3429 - val_loss: 2.4399
# Epoch 147/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3196 - loss: 2.5483 - val_accuracy: 0.3429 - val_loss: 2.4279
# Epoch 148/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3089 - loss: 2.5597 - val_accuracy: 0.3318 - val_loss: 2.4451
# Epoch 149/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3156 - loss: 2.5529 - val_accuracy: 0.3411 - val_loss: 2.4478
# Epoch 150/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3200 - loss: 2.5642 - val_accuracy: 0.3401 - val_loss: 2.4332
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                           precision    recall  f1-score   support
#
#              alarm_query       0.31      0.53      0.39        19
#             alarm_remove       1.00      0.09      0.17        11
#                alarm_set       0.42      0.84      0.56        19
#        audio_volume_down       0.50      0.38      0.43         8
#        audio_volume_mute       0.33      0.13      0.19        15
#          audio_volume_up       0.38      0.46      0.41        13
#           calendar_query       0.18      0.11      0.13        19
#          calendar_remove       0.41      0.47      0.44        19
#             calendar_set       0.17      0.21      0.19        19
#           cooking_recipe       0.17      0.16      0.16        19
#         datetime_convert       0.00      0.00      0.00         8
#           datetime_query       0.22      0.74      0.33        19
#         email_addcontact       0.75      0.38      0.50         8
#              email_query       0.44      0.37      0.40        19
#       email_querycontact       0.00      0.00      0.00        19
#          email_sendemail       0.39      0.58      0.47        19
#           general_affirm       0.59      0.53      0.56        19
#      general_commandstop       0.88      0.79      0.83        19
#          general_confirm       1.00      0.89      0.94        19
#         general_dontcare       0.29      0.53      0.37        19
#          general_explain       0.29      0.26      0.28        19
#             general_joke       0.22      0.17      0.19        12
#           general_negate       0.60      0.47      0.53        19
#           general_praise       0.56      0.79      0.65        19
#           general_quirky       0.00      0.00      0.00        19
#           general_repeat       0.42      0.84      0.56        19
#             iot_cleaning       0.85      0.69      0.76        16
#               iot_coffee       0.82      0.47      0.60        19
#      iot_hue_lightchange       0.48      0.53      0.50        19
#         iot_hue_lightdim       0.18      0.17      0.17        12
#         iot_hue_lightoff       0.60      0.79      0.68        19
#          iot_hue_lighton       0.00      0.00      0.00         3
#          iot_hue_lightup       0.26      0.36      0.30        14
#             iot_wemo_off       0.60      0.33      0.43         9
#              iot_wemo_on       0.33      0.14      0.20         7
#        lists_createoradd       0.50      0.58      0.54        19
#              lists_query       0.20      0.11      0.14        19
#             lists_remove       0.40      0.32      0.35        19
#           music_likeness       0.17      0.11      0.13        18
#              music_query       0.14      0.16      0.15        19
#           music_settings       0.00      0.00      0.00         7
#               news_query       0.13      0.11      0.12        19
#           play_audiobook       0.11      0.11      0.11        19
#                play_game       0.26      0.37      0.30        19
#               play_music       0.75      0.16      0.26        19
#            play_podcasts       0.35      0.42      0.38        19
#               play_radio       0.09      0.05      0.07        19
#              qa_currency       0.32      0.58      0.42        19
#            qa_definition       0.10      0.05      0.07        19
#               qa_factoid       0.13      0.11      0.12        19
#                 qa_maths       0.27      0.50      0.35        14
#                 qa_stock       0.23      0.32      0.27        19
#    recommendation_events       0.26      0.53      0.34        19
# recommendation_locations       0.00      0.00      0.00        19
#    recommendation_movies       0.00      0.00      0.00        10
#              social_post       0.17      0.11      0.13        19
#             social_query       0.00      0.00      0.00        18
#           takeaway_order       0.17      0.16      0.16        19
#           takeaway_query       1.00      0.05      0.10        19
#          transport_query       0.11      0.21      0.15        19
#           transport_taxi       0.32      0.56      0.41        18
#         transport_ticket       0.47      0.84      0.60        19
#        transport_traffic       0.36      0.26      0.30        19
#            weather_query       0.40      0.11      0.17        19
#
#                 accuracy                           0.35      1076
#                macro avg       0.34      0.33      0.30      1076
#             weighted avg       0.35      0.35      0.32      1076

# %% [markdown]
# **Task 3: Mô hình Nâng cao (Embedding Pre-trained + LSTM)**

# %%
# 1. Tiền xử lý cho mô hình chuỗi
# a. Tokenizer: Tạo vocab và chuyển text thành chuỗi chỉ số
tokenizer = Tokenizer(oov_token="<UNK>")
tokenizer.fit_on_texts(pd.concat([df_train['text'], df_val['text']]))
train_sequences = tokenizer.texts_to_sequences(df_train['text'])
val_sequences = tokenizer.texts_to_sequences(df_val['text'])
test_sequences = tokenizer.texts_to_sequences(df_test['text'])

# b. Padding: Đảm bảo các chuỗi có cùng độ dài
max_len = 50
X_train_pad = pad_sequences(train_sequences, maxlen=max_len, padding='post')
X_val_pad = pad_sequences(val_sequences, maxlen=max_len, padding='post')
X_test_pad = pad_sequences(test_sequences, maxlen=max_len, padding='post')

# 2. Tạo ma trận trọng số cho Embedding Layer từ Word2Vec
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = w2v_model.vector_size
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in tokenizer.word_index.items():
    if word in w2v_model.wv:
        embedding_matrix[i] = w2v_model.wv[word]

# 3. Xây dựng mô hình Sequential với LSTM
lstm_model_pretrained = Sequential([
    Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        # Khởi tạo trọng số
        weights=[embedding_matrix],
        input_length=max_len,
        # Đóng băng lớp Embedding
        trainable=False),
    LSTM(128, dropout=0.2, recurrent_dropout=0.2),
    Dense(len(labelEncoder.classes_), activation='softmax')])

# 4. Compile, huấn luyện (sử dụng EarlyStopping) và đánh giá
lstm_model_pretrained.compile(optimizer='adam',
                              loss='sparse_categorical_crossentropy',
                              metrics=['accuracy'])
lstm_model_pretrained.summary()
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = lstm_model_pretrained.fit(X_train_pad, y_train,
                                    validation_data=(X_val_pad, y_val),
                                    epochs=150,
                                    batch_size=64,
                                    callbacks=[early_stopping])
print(classification_report(y_test, lstm_model_pretrained.predict(X_test_pad).argmax(axis=1), target_names=labelEncoder.classes_))
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │       446,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 446,400 (1.70 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 446,400 (1.70 MB)
# Epoch 1/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - accuracy: 0.0148 - loss: 4.1493 - val_accuracy: 0.0335 - val_loss: 4.0594
# Epoch 2/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.0280 - loss: 4.0631 - val_accuracy: 0.0586 - val_loss: 3.8880
# Epoch 3/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.0462 - loss: 3.9568 - val_accuracy: 0.0548 - val_loss: 3.9517
# Epoch 4/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.0472 - loss: 3.9202 - val_accuracy: 0.0660 - val_loss: 3.8092
# Epoch 5/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.0545 - loss: 3.8492 - val_accuracy: 0.0762 - val_loss: 3.7591
# Epoch 6/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0529 - loss: 3.8371 - val_accuracy: 0.0716 - val_loss: 3.7283
# Epoch 7/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0571 - loss: 3.8147 - val_accuracy: 0.0827 - val_loss: 3.7246
# Epoch 8/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.0663 - loss: 3.7772 - val_accuracy: 0.0911 - val_loss: 3.6874
# Epoch 9/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0641 - loss: 3.7571 - val_accuracy: 0.0874 - val_loss: 3.6819
# Epoch 10/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0662 - loss: 3.7314 - val_accuracy: 0.0939 - val_loss: 3.6624
# Epoch 11/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.0699 - loss: 3.7112 - val_accuracy: 0.0836 - val_loss: 3.6502
# Epoch 12/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0743 - loss: 3.6908 - val_accuracy: 0.1004 - val_loss: 3.5970
# Epoch 13/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.0691 - loss: 3.6709 - val_accuracy: 0.0985 - val_loss: 3.5821
# Epoch 14/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0838 - loss: 3.6326 - val_accuracy: 0.0939 - val_loss: 3.5553
# Epoch 15/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0813 - loss: 3.6157 - val_accuracy: 0.0511 - val_loss: 4.0608
# Epoch 16/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0625 - loss: 3.7949 - val_accuracy: 0.0901 - val_loss: 3.5312
# Epoch 17/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.0767 - loss: 3.6587 - val_accuracy: 0.1069 - val_loss: 3.4687
# Epoch 18/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.0752 - loss: 3.6742 - val_accuracy: 0.0771 - val_loss: 3.5914
# Epoch 19/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.0646 - loss: 3.6798 - val_accuracy: 0.0809 - val_loss: 3.5329
# Epoch 20/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0771 - loss: 3.6048 - val_accuracy: 0.0864 - val_loss: 3.4950
# Epoch 21/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.
150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.3827 - loss: 2.1821 - val_accuracy: 0.4303 - val_loss: 2.0461
# Epoch 150/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.4008 - loss: 2.1417 - val_accuracy: 0.4377 - val_loss: 2.0470
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#                           precision    recall  f1-score   support
#
#              alarm_query       0.61      0.58      0.59        19
#             alarm_remove       0.80      0.73      0.76        11
#                alarm_set       0.68      0.79      0.73        19
#        audio_volume_down       0.50      0.38      0.43         8
#        audio_volume_mute       0.31      0.27      0.29        15
#          audio_volume_up       0.64      0.54      0.58        13
#           calendar_query       0.31      0.21      0.25        19
#          calendar_remove       0.43      0.53      0.48        19
#             calendar_set       0.17      0.21      0.19        19
#           cooking_recipe       0.19      0.16      0.17        19
#         datetime_convert       0.19      0.62      0.29         8
#           datetime_query       0.23      0.63      0.33        19
#         email_addcontact       0.00      0.00      0.00         8
#              email_query       0.44      0.21      0.29        19
#       email_querycontact       0.10      0.11      0.10        19
#          email_sendemail       0.30      0.37      0.33        19
#           general_affirm       0.43      0.68      0.53        19
#      general_commandstop       0.84      0.84      0.84        19
#          general_confirm       1.00      0.89      0.94        19
#         general_dontcare       0.61      0.58      0.59        19
#          general_explain       0.73      0.58      0.65        19
#             general_joke       0.20      0.08      0.12        12
#           general_negate       0.69      0.47      0.56        19
#           general_praise       0.45      0.68      0.54        19
#           general_quirky       0.00      0.00      0.00        19
#           general_repeat       0.62      0.84      0.71        19
#             iot_cleaning       0.81      0.81      0.81        16
#               iot_coffee       0.59      0.53      0.56        19
#      iot_hue_lightchange       0.54      0.68      0.60        19
#         iot_hue_lightdim       0.40      0.50      0.44        12
#         iot_hue_lightoff       0.82      0.74      0.78        19
#          iot_hue_lighton       0.00      0.00      0.00         3
#          iot_hue_lightup       0.33      0.29      0.31        14
#             iot_wemo_off       0.57      0.44      0.50         9
#              iot_wemo_on       0.40      0.29      0.33         7
#        lists_createoradd       0.54      0.68      0.60        19
#              lists_query       0.50      0.32      0.39        19
#             lists_remove       0.45      0.26      0.33        19
#           music_likeness       0.12      0.11      0.12        18
#              music_query       0.05      0.11      0.06        19
#           music_settings       0.43      0.43      0.43         7
#               news_query       0.18      0.11      0.13        19
#           play_audiobook       0.21      0.16      0.18        19
#                play_game       0.35      0.42      0.38        19
#               play_music       0.25      0.21      0.23        19
#            play_podcasts       0.42      0.42      0.42        19
#               play_radio       0.35      0.32      0.33        19
#              qa_currency       0.32      0.42      0.36        19
#            qa_definition       0.24      0.63      0.34        19
#               qa_factoid       0.20      0.32      0.24        19
#                 qa_maths       0.25      0.21      0.23        14
#                 qa_stock       0.10      0.05      0.07        19
#    recommendation_events       0.31      0.26      0.29        19
# recommendation_locations       0.00      0.00      0.00        19
#    recommendation_movies       0.00      0.00      0.00        10
#              social_post       0.17      0.21      0.19        19
#             social_query       0.50      0.11      0.18        18
#           takeaway_order       0.36      0.21      0.27        19
#           takeaway_query       0.30      0.37      0.33        19
#          transport_query       0.44      0.42      0.43        19
#           transport_taxi       0.76      0.72      0.74        18
#         transport_ticket       0.69      0.58      0.63        19
#        transport_traffic       0.44      0.37      0.40        19
#            weather_query       0.18      0.11      0.13        19
#
#                 accuracy                           0.40      1076
#                macro avg       0.39      0.39      0.38      1076
#             weighted avg       0.40      0.40      0.39      1076

# %% [markdown]
# **Task 4: Mô hình Nâng cao (Embedding học từ đầu + LSTM)**

# %%
# 1. Xây dựng mô hình
lstm_model_scratch = Sequential([
    Embedding(input_dim=vocab_size,
              output_dim=100,  # Chọn một chiều embedding, ví dụ 100
              input_length=max_len,
              trainable=True),  # Không có weights từ Word2Vec, học từ đầu
    LSTM(128, dropout=0.2, recurrent_dropout=0.2),
    Dense(len(labelEncoder.classes_), activation='softmax')])

# 2. Compile, huấn luyện và đánh giá mô hình
lstm_model_scratch.compile(optimizer='adam',
                           loss='sparse_categorical_crossentropy',
                           metrics=['accuracy'])

lstm_model_scratch.summary()

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = lstm_model_scratch.fit(X_train_pad, y_train,
                                 validation_data=(X_val_pad, y_val),
                                 epochs=150,
                                 batch_size=64,
                                 callbacks=[early_stopping],
                                 verbose=1)

print("\nScratch Embedding + LSTM Classification Report:")
print(classification_report(y_test, lstm_model_scratch.predict(X_test_pad).argmax(axis=1), target_names=labelEncoder.classes_))
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.0186 - loss: 4.1502 - val_accuracy: 0.0177 - val_loss: 4.1302
# Epoch 2/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.0145 - loss: 4.1355 - val_accuracy: 0.0177 - val_loss: 4.1291
# Epoch 3/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.0196 - loss: 4.1344 - val_accuracy: 0.0177 - val_loss: 4.1286
# Epoch 4/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.0160 - loss: 4.1333 - val_accuracy: 0.0177 - val_loss: 4.1286
# Epoch 5/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.0168 - loss: 4.1322 - val_accuracy: 0.0177 - val_loss: 4.1284
# Epoch 6/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.0129 - loss: 4.1331 - val_accuracy: 0.0177 - val_loss: 4.1275
# Epoch 7/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.0149 - loss: 4.1284 - val_accuracy: 0.0232 - val_loss: 4.0486
# Epoch 8/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.0544 - loss: 3.8115 - val_accuracy: 0.0623 - val_loss: 3.5571
# Epoch 9/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.0682 - loss: 3.4663 - val_accuracy: 0.0697 - val_loss: 3.4413
# Epoch 10/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.0905 - loss: 3.2048 - val_accuracy: 0.1143 - val_loss: 3.1894
# Epoch 11/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.1107 - loss: 3.0250 - val_accuracy: 0.1013 - val_loss: 3.1205
# Epoch 12/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.1260 - loss: 2.8882 - val_accuracy: 0.0362 - val_loss: 3.5994
# Epoch 13/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.1155 - loss: 2.8846 - val_accuracy: 0.0855 - val_loss: 3.2311
# Epoch 14/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.1310 - loss: 2.7493 - val_accuracy: 0.1366 - val_loss: 3.0273
# Epoch 15/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.1493 - loss: 2.6031 - val_accuracy: 0.1422 - val_loss: 3.0385
# Epoch 16/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.1734 - loss: 2.5155 - val_accuracy: 0.1217 - val_loss: 3.1001
# Epoch 17/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.1729 - loss: 2.4703 - val_accuracy: 0.0976 - val_loss: 3.2587
# Epoch 18/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.1489 - loss: 2.5400 - val_accuracy: 0.1989 - val_loss: 2.7882
# Epoch 19/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.1304 - loss: 2.6591 - val_accuracy: 0.0688 - val_loss: 3.2823
# Epoch 20/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.1309 - loss: 2.6609 - val_accuracy: 0.0864 - val_loss: 3.1489
# Epoch 21/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.1628 - loss: 2.4519 - val_accuracy: 0.1691 - val_loss: 2.8696
# Epoch 22/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.2040 - loss: 2.2781 - val_accuracy: 0.1868 - val_loss: 2.8378
# Epoch 23/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.2234 - loss: 2.1974 - val_accuracy: 0.2072 - val_loss: 2.8207
# Epoch 24/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.2326 - loss: 2.1640 - val_accuracy: 0.2212 - val_loss: 2.8079
# Epoch 25/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.2239 - loss: 2.1845 - val_accuracy: 0.1626 - val_loss: 2.9384
# Epoch 26/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.2060 - loss: 2.2975 - val_accuracy: 0.1747 - val_loss: 2.9039
# Epoch 27/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.1786 - loss: 2.2944 - val_accuracy: 0.2138 - val_loss: 2.8374
# Epoch 28/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2242 - loss: 2.1386 - val_accuracy: 0.2165 - val_loss: 2.7646
# Epoch 29/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.2625 - loss: 2.0338 - val_accuracy: 0.2435 - val_loss: 2.7504
# Epoch 30/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.2731 - loss: 1.9734 - val_accuracy: 0.2193 - val_loss: 2.8331
# Epoch 31/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2743 - loss: 1.9645 - val_accuracy: 0.2500 - val_loss: 2.7985
# Epoch 32/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2929 - loss: 1.9428 - val_accuracy: 0.2584 - val_loss: 2.8039
# Epoch 33/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2759 - loss: 1.9811 - val_accuracy: 0.1394 - val_loss: 3.0516
# Epoch 34/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2313 - loss: 2.0946 - val_accuracy: 0.1877 - val_loss: 2.9562
# Epoch 35/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2749 - loss: 1.9768 - val_accuracy: 0.1933 - val_loss: 2.8920
# Epoch 36/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2514 - loss: 1.9768 - val_accuracy: 0.1552 - val_loss: 2.9801
# Epoch 37/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2383 - loss: 2.0656 - val_accuracy: 0.2463 - val_loss: 2.7620
# Epoch 38/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2474 - loss: 2.0239 - val_accuracy: 0.2156 - val_loss: 2.8570
# Epoch 39/150
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.2522 - loss: 2.0267 - val_accuracy: 0.2537 - val_loss: 2.8173
#
# Scratch Embedding + LSTM Classification Report:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#                           precision    recall  f1-score   support
#
#              alarm_query       0.00      0.00      0.00        19
#             alarm_remove       0.00      0.00      0.00        11
#                alarm_set       0.24      0.58      0.34        19
#        audio_volume_down       0.00      0.00      0.00         8
#        audio_volume_mute       0.00      0.00      0.00        15
#          audio_volume_up       0.60      0.23      0.33        13
#           calendar_query       0.00      0.00      0.00        19
#          calendar_remove       0.00      0.00      0.00        19
#             calendar_set       0.12      0.16      0.14        19
#           cooking_recipe       0.05      0.05      0.05        19
#         datetime_convert       0.00      0.00      0.00         8
#           datetime_query       0.22      0.21      0.22        19
#         email_addcontact       0.00      0.00      0.00         8
#              email_query       0.21      0.32      0.25        19
#       email_querycontact       0.20      0.47      0.28        19
#          email_sendemail       0.19      0.63      0.29        19
#           general_affirm       0.59      0.89      0.71        19
#      general_commandstop       0.00      0.00      0.00        19
#          general_confirm       0.44      0.84      0.58        19
#         general_dontcare       0.38      0.84      0.52        19
#          general_explain       0.00      0.00      0.00        19
#             general_joke       0.00      0.00      0.00        12
#           general_negate       0.32      0.37      0.34        19
#           general_praise       0.38      0.74      0.50        19
#           general_quirky       0.00      0.00      0.00        19
#           general_repeat       0.26      0.68      0.38        19
#             iot_cleaning       0.00      0.00      0.00        16
#               iot_coffee       0.00      0.00      0.00        19
#      iot_hue_lightchange       0.32      0.74      0.44        19
#         iot_hue_lightdim       0.00      0.00      0.00        12
#         iot_hue_lightoff       0.21      0.42      0.28        19
#          iot_hue_lighton       0.00      0.00      0.00         3
#          iot_hue_lightup       0.00      0.00      0.00        14
#             iot_wemo_off       0.20      0.67      0.31         9
#              iot_wemo_on       0.00      0.00      0.00         7
#        lists_createoradd       0.20      0.63      0.31        19
#              lists_query       0.00      0.00      0.00        19
#             lists_remove       0.26      0.58      0.35        19
#           music_likeness       0.12      0.06      0.08        18
#              music_query       0.29      0.53      0.37        19
#           music_settings       0.00      0.00      0.00         7
#               news_query       0.00      0.00      0.00        19
#           play_audiobook       0.22      0.11      0.14        19
#                play_game       0.19      0.53      0.28        19
#               play_music       0.15      0.32      0.20        19
#            play_podcasts       0.00      0.00      0.00        19
#               play_radio       0.00      0.00      0.00        19
#              qa_currency       0.37      0.53      0.43        19
#            qa_definition       0.28      0.58      0.38        19
#               qa_factoid       0.00      0.00      0.00        19
#                 qa_maths       0.00      0.00      0.00        14
#                 qa_stock       0.50      0.53      0.51        19
#    recommendation_events       0.25      0.21      0.23        19
# recommendation_locations       0.29      0.11      0.15        19
#    recommendation_movies       0.00      0.00      0.00        10
#              social_post       0.25      0.26      0.26        19
#             social_query       0.00      0.00      0.00        18
#           takeaway_order       0.42      0.53      0.47        19
#           takeaway_query       0.33      0.53      0.41        19
#          transport_query       0.00      0.00      0.00        19
#           transport_taxi       0.50      0.17      0.25        18
#         transport_ticket       0.26      0.53      0.35        19
#        transport_traffic       0.36      0.21      0.27        19
#            weather_query       0.00      0.00      0.00        19
#
#                 accuracy                           0.27      1076
#                macro avg       0.16      0.25      0.18      1076
#             weighted avg       0.17      0.27      0.20      1076

# %% [markdown]
# **Task 5: Đánh giá, So sánh và Phân tích**

# %%
# 1. Bảng tổng hợp F1-score (macro) và Test Loss cho 4 pipeline
def safe_predict_proba(model, X):
    try:
        return model.predict_proba(X)
    except Exception:
        return None

# TF-IDF + Logistic Regression metrics
y_pred_tfidf = tfidf_lr_pipeline.predict(df_test['text'])
y_proba_tfidf = safe_predict_proba(tfidf_lr_pipeline, df_test['text'])
tfidf_macro_f1 = f1_score(y_test, y_pred_tfidf, average='macro')
tfidf_test_loss = log_loss(y_test, y_proba_tfidf) if y_proba_tfidf is not None else None

# Word2Vec (Avg) + Dense metrics
y_proba_avg = model.predict(X_test_avg)
y_pred_avg = y_proba_avg.argmax(axis=1)
avg_macro_f1 = f1_score(y_test, y_pred_avg, average='macro')
avg_test_loss = log_loss(y_test, y_proba_avg)

# Pretrained Embedding + LSTM metrics
y_proba_lstm_pre = lstm_model_pretrained.predict(X_test_pad)
y_pred_lstm_pre = y_proba_lstm_pre.argmax(axis=1)
pre_macro_f1 = f1_score(y_test, y_pred_lstm_pre, average='macro')
pre_test_loss = log_loss(y_test, y_proba_lstm_pre)

# Scratch Embedding + LSTM metrics
y_proba_lstm_scratch = lstm_model_scratch.predict(X_test_pad)
y_pred_lstm_scratch = y_proba_lstm_scratch.argmax(axis=1)
scratch_macro_f1 = f1_score(y_test, y_pred_lstm_scratch, average='macro')
scratch_test_loss = log_loss(y_test, y_proba_lstm_scratch)

results_df = pd.DataFrame({
    'Pipeline': ['TF-IDF + Logistic Regression', 'Word2Vec (Avg) + Dense', 'Embedding (Pre-trained) + LSTM', 'Embedding (Scratch) + LSTM'],
    'F1-score (Macro)': [tfidf_macro_f1, avg_macro_f1, pre_macro_f1, scratch_macro_f1],
    'Test Loss': [tfidf_test_loss, avg_test_loss, pre_test_loss, scratch_test_loss]
})
print('\n=== Bảng Tổng Hợp Kết Quả ===')
display(results_df)

# 2. Phân tích định tính với các câu khó
difficult_sentences = [
    ('can you remind me to not call my mom', 'reminder_create'),
    ('is it going to be sunny or rainy tomorrow', 'weather_query'),
    ('find a flight from new york to london but not through paris', 'flight_search')
]

def predict_pipeline(sentence):
    # TF-IDF
    p_tfidf_idx = tfidf_lr_pipeline.predict([sentence])[0]
    p_tfidf = labelEncoder.inverse_transform([p_tfidf_idx])[0]
    # Word2Vec avg
    avg_vec = np.array([sentence_to_avg_vector(sentence, w2v_model)])
    p_avg_idx = model.predict(avg_vec).argmax(axis=1)[0]
    p_avg = labelEncoder.inverse_transform([p_avg_idx])[0]
    # Pretrained LSTM
    seq_pre = pad_sequences(tokenizer.texts_to_sequences([sentence]), maxlen=max_len, padding='post')
    p_pre_idx = lstm_model_pretrained.predict(seq_pre).argmax(axis=1)[0]
    p_pre = labelEncoder.inverse_transform([p_pre_idx])[0]
    # Scratch LSTM
    p_scr_idx = lstm_model_scratch.predict(seq_pre).argmax(axis=1)[0]
    p_scr = labelEncoder.inverse_transform([p_scr_idx])[0]
    return p_tfidf, p_avg, p_pre, p_scr

analysis_rows = []
for sent, true_label in difficult_sentences:
    ptfidf, pavg, ppre, pscr = predict_pipeline(sent)
    analysis_rows.append({
        'Sentence': sent,
        'True Intent': true_label,
        'TF-IDF+LR': ptfidf,
        'W2V Avg + Dense': pavg,
        'Pretrained LSTM': ppre,
        'Scratch LSTM': pscr
    })

qual_df = pd.DataFrame(analysis_rows)
print('\n=== Phân Tích Định Tính Các Câu Khó ===')
display(qual_df)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# === Bảng Tổng Hợp Kết Quả ===
#                          Pipeline  F1-score (Macro)  Test Loss
# 0    TF-IDF + Logistic Regression          0.835298   1.050197
# 1          Word2Vec (Avg) + Dense          0.304154   2.452722
# 2  Embedding (Pre-trained) + LSTM          0.376478   2.108491
# 3      Embedding (Scratch) + LSTM          0.178246   2.868297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# === Phân Tích Định Tính Các Câu Khó ===
#                                             Sentence      True Intent  \
# 0               can you remind me to not call my mom  reminder_create
# 1          is it going to be sunny or rainy tomorrow    weather_query
# 2  find a flight from new york to london but not ...    flight_search
#
#         TF-IDF+LR  W2V Avg + Dense  Pretrained LSTM     Scratch LSTM
# 0    calendar_set   general_quirky   takeaway_query  email_sendemail
# 1   weather_query         qa_maths         qa_maths   takeaway_order
# 2  general_negate  transport_query  email_sendemail     calendar_set
